# %%
from flux.datasets.vqa import coco_caption
import os
# Out:
# [Flux] Initializing...

# %%
coco = coco_caption.CocoCaption(validation_only=True)

# %%
import numpy as np

# %%
index = coco.build_index(False)

# %%
g = coco.val_data_stream()

# %%
import matplotlib.pyplot as plt

for i in range(500):
    img, question, answer = next(g)

    if i % 100 == 0:
        plt.imshow(img)
        plt.show()
        print(question)
        print(answer)
# Out:
# What does the sentence on the top say?
# this is camping
# What does the last sign say?
# ross st
# Is there a person riding a bike?
# no
# What is being celebrated?
# birthday
# How many cats are in the image?
# 1
